# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !cd /content/
# !rm -rf ./phd_utils/
# !git clone -b experiment_utils https://ay94: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@github.com/ay94/phd_utils.git
# !pip install -e phd_utils/
# Out:
# Cloning into 'phd_utils'...
# remote: Enumerating objects: 425, done.
# remote: Counting objects: 100% (208/208), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 425 (delta 98), reused 197 (delta 88), pack-reused 217
# Receiving objects: 100% (425/425), 81.79 KiB | 891.00 KiB/s, done.
# Resolving deltas: 100% (187/187), done.
# Obtaining file:///content/phd_utils
#   Preparing metadata (setup.py) ... done
# Installing collected packages: experiment-utils
#   Running setup.py develop for experiment-utils
# Successfully installed experiment-utils-0.1.0

# %%
# !pip install seqeval
# !pip install farasapy
# !pip install pyarabic
# !pip install umap-learn
# !pip install transformers
# !git clone https://github.com/aub-mind/arabert
# Out:
# Requirement already satisfied: seqeval in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.2.0)
# Requirement already satisfied: farasapy in /usr/local/lib/python3.10/dist-packages (0.0.14)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from farasapy) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from farasapy) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (3.4)
# Requirement already satisfied: pyarabic in /usr/local/lib/python3.10/dist-packages (0.6.15)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from pyarabic) (1.16.0)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.65.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (67.7.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# fatal: destination path 'arabert' already exists and is not an empty directory.

# %%
cd /content/phd_utils/
# Out:
# /content/phd_utils

# %%
import experiment_utils
import importlib
from experiment_utils import utils
from experiment_utils.finetune_utils import *
from experiment_utils.model_outputs_utils import *
from experiment_utils.error_analysis import *
importlib.reload(utils)
# Out:
# <module 'experiment_utils.utils' from '/content/phd_utils/experiment_utils/utils.py'>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import ast
import math
import copy
import time
import torch
import warnings
import numpy as np
import pandas as pd
from torch import nn
import pickle as pkl
from umap import UMAP
from scipy.spatial import distance
import plotly.express as px
import matplotlib.pyplot as plt
from torch.optim import AdamW
from tqdm.notebook import tqdm
from sklearn.cluster import KMeans
from collections import defaultdict, Counter
from arabert.preprocess import ArabertPreprocessor
from sklearn.metrics import silhouette_samples, silhouette_score
from transformers import AutoTokenizer, AutoModel, get_linear_schedule_with_warmup
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from seqeval.metrics import accuracy_score as seq_accuracy, f1_score as seq_f1, precision_score as seq_precision, recall_score as seq_recall, classification_report as seq_classification
from sklearn.metrics import accuracy_score as skl_accuracy, f1_score as skl_f1, precision_score as skl_precision, recall_score as skl_recall, classification_report as skl_classification

# %%
DATA_FOLDER = '/content/drive/MyDrive/Final Year Experiments/Class Imbalance/1_fineTuning'
fh = utils.FileHandler(DATA_FOLDER)

OUTPUT_FOLDER = '/content/drive/MyDrive/Final Year Experiments/Class Imbalance/2_modelOutputs'
model_out_fh = utils.FileHandler(OUTPUT_FOLDER)

# %%
arabertv02_path = 'aubmindlab/bert-base-arabertv02'
data_name = 'ANERCorp_CamelLab'
model_name = 'arabertv02'
ANERCorp_FOLDER = f'/content/drive/MyDrive/Final Year Experiments/Class Imbalance/3_errorAnalysis/Test/{data_name}'
aner_fh = utils.FileHandler(ANERCorp_FOLDER)

# %%
analysis_outputs = AnalysisOutputs(fh, aner_fh, data_name, model_name, arabertv02_path, arabertv02_path)
# Out:
# Generate Training Batches
#   0%|          | 0/213 [00:00<?, ?it/s]
# Compute Outputs
# Generate Validation Batches
#   0%|          | 0/94 [00:00<?, ?it/s]
# Compute Outputs
# Generate Test Batches
#   0%|          | 0/121 [00:00<?, ?it/s]
# Compute Outputs
# Loading Preprocessor aubmindlab/bert-base-arabertv02
# Loading Tokenizer aubmindlab/bert-base-arabertv02
# Downloading (…)okenizer_config.json:   0%|          | 0.00/381 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/825k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.64M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Generate Training Tokenization Outputs
#   0%|          | 0/3402 [00:00<?, ?it/s]
# Generate Validation Tokenization Outputs
#   0%|          | 0/747 [00:00<?, ?it/s]
# Generate Test Tokenization Outputs
#   0%|          | 0/961 [00:00<?, ?it/s]
# Generate Training Subwords Locations
#   0%|          | 0/3402 [00:00<?, ?it/s]
# Generate Validation Subwords Locations
#   0%|          | 0/747 [00:00<?, ?it/s]
# Generate Test Subwords Locations
#   0%|          | 0/961 [00:00<?, ?it/s]

# %%
analysis_outputs.save_analysis('train')
# Out:
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 19:43:35 2023 Construct fuzzy simplicial set
# Wed Aug  2 19:43:36 2023 Finding Nearest Neighbors
# Wed Aug  2 19:43:36 2023 Building RP forest with 22 trees
# Wed Aug  2 19:43:43 2023 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	 5  /  17
# 	 6  /  17
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 19:44:02 2023 Finished Nearest Neighbor Search
# Wed Aug  2 19:44:05 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 19:45:55 2023 Finished embedding
# Compute Consistency
#   0%|          | 0/119921 [00:00<?, ?it/s]
# Compute Token Ambiguity
#   0%|          | 0/20999 [00:00<?, ?it/s]
#   0%|          | 0/119921 [00:00<?, ?it/s]
# Compute Word Ambiguity
#   0%|          | 0/25888 [00:00<?, ?it/s]
#   0%|          | 0/119921 [00:00<?, ?it/s]
# Generate Analysis Data
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 19:54:36 2023 Construct fuzzy simplicial set
# Wed Aug  2 19:54:37 2023 Finding Nearest Neighbors
# Wed Aug  2 19:54:37 2023 Building RP forest with 21 trees
# Wed Aug  2 19:54:39 2023 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	 5  /  17
# 	 6  /  17
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 19:54:44 2023 Finished Nearest Neighbor Search
# Wed Aug  2 19:54:45 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 19:56:12 2023 Finished embedding
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 19:56:24 2023 Construct fuzzy simplicial set
# Wed Aug  2 19:56:24 2023 Finding Nearest Neighbors
# Wed Aug  2 19:56:24 2023 Building RP forest with 21 trees
# Wed Aug  2 19:56:27 2023 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	 5  /  17
# 	 6  /  17
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 19:56:32 2023 Finished Nearest Neighbor Search
# Wed Aug  2 19:56:33 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 19:57:58 2023 Finished embedding
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 19:58:29 2023 Construct fuzzy simplicial set
# Wed Aug  2 19:58:29 2023 Finding Nearest Neighbors
# Wed Aug  2 19:58:29 2023 Building RP forest with 21 trees
# Wed Aug  2 19:58:31 2023 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	 5  /  17
# 	 6  /  17
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 19:58:37 2023 Finished Nearest Neighbor Search
# Wed Aug  2 19:58:37 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:00:03 2023 Finished embedding
# Generate Prediction Data
# Generate Scores Data
# Generate Training Impact Data
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
analysis_outputs.save_analysis('val')
# Out:
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:11:50 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:11:50 2023 Finding Nearest Neighbors
# Wed Aug  2 20:11:50 2023 Building RP forest with 13 trees
# Wed Aug  2 20:11:50 2023 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 20:11:52 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:11:52 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:12:12 2023 Finished embedding
# Compute Consistency
#   0%|          | 0/27161 [00:00<?, ?it/s]
# Compute Token Ambiguity
#   0%|          | 0/20999 [00:00<?, ?it/s]
#   0%|          | 0/27161 [00:00<?, ?it/s]
# Compute Word Ambiguity
#   0%|          | 0/25888 [00:00<?, ?it/s]
#   0%|          | 0/27161 [00:00<?, ?it/s]
# Generate Analysis Data
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:14:13 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:14:13 2023 Finding Nearest Neighbors
# Wed Aug  2 20:14:13 2023 Building RP forest with 13 trees
# Wed Aug  2 20:14:14 2023 NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	 4  /  14
# 	 5  /  14
# 	 6  /  14
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 20:14:15 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:14:15 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:14:32 2023 Finished embedding
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:14:36 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:14:36 2023 Finding Nearest Neighbors
# Wed Aug  2 20:14:36 2023 Building RP forest with 13 trees
# Wed Aug  2 20:14:36 2023 NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	 4  /  14
# 	 5  /  14
# 	 6  /  14
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 20:14:37 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:14:37 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:14:56 2023 Finished embedding
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:15:05 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:15:05 2023 Finding Nearest Neighbors
# Wed Aug  2 20:15:05 2023 Building RP forest with 13 trees
# Wed Aug  2 20:15:06 2023 NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	 4  /  14
# 	 5  /  14
# 	 6  /  14
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 20:15:07 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:15:07 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:15:23 2023 Finished embedding
# Generate Prediction Data
# Generate Scores Data
# Generate Training Impact Data
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
analysis_outputs.save_analysis('test')
# Out:
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:17:11 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:17:11 2023 Finding Nearest Neighbors
# Wed Aug  2 20:17:11 2023 Building RP forest with 14 trees
# Wed Aug  2 20:17:11 2023 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 20:17:13 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:17:13 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:17:34 2023 Finished embedding
# Compute Consistency
#   0%|          | 0/29711 [00:00<?, ?it/s]
# Compute Token Ambiguity
#   0%|          | 0/20999 [00:00<?, ?it/s]
#   0%|          | 0/29711 [00:00<?, ?it/s]
# Compute Word Ambiguity
#   0%|          | 0/25888 [00:00<?, ?it/s]
#   0%|          | 0/29711 [00:00<?, ?it/s]
# Generate Analysis Data
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:19:45 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:19:45 2023 Finding Nearest Neighbors
# Wed Aug  2 20:19:45 2023 Building RP forest with 13 trees
# Wed Aug  2 20:19:45 2023 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 20:19:46 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:19:47 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:20:05 2023 Finished embedding
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:20:08 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:20:08 2023 Finding Nearest Neighbors
# Wed Aug  2 20:20:08 2023 Building RP forest with 13 trees
# Wed Aug  2 20:20:08 2023 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 20:20:10 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:20:10 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:20:28 2023 Finished embedding
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:20:37 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:20:37 2023 Finding Nearest Neighbors
# Wed Aug  2 20:20:37 2023 Building RP forest with 13 trees
# Wed Aug  2 20:20:38 2023 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	Stopping threshold met -- exiting after 6 iterations
# Wed Aug  2 20:20:39 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:20:39 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:20:57 2023 Finished embedding
# Generate Prediction Data
# Generate Scores Data
# Generate Training Impact Data
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
pretrained_training_output = AuxilariyOutputs(model_name, data_name, arabertv02_path, fh, aner_fh)
# Out:
# Loading BERT Model: aubmindlab/bert-base-arabertv02
# Generate Training Batches
#   0%|          | 0/213 [00:00<?, ?it/s]
# Compute Outputs
# Generate Validation Batches
#   0%|          | 0/94 [00:00<?, ?it/s]
# Compute Outputs
# Generate Test Batches
#   0%|          | 0/121 [00:00<?, ?it/s]
# Compute Outputs

# %%
pretrained_training_output.save('train')
# Out:
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:23:05 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:23:06 2023 Finding Nearest Neighbors
# Wed Aug  2 20:23:06 2023 Building RP forest with 22 trees
# Wed Aug  2 20:23:07 2023 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	 5  /  17
# 	 6  /  17
# 	 7  /  17
# 	 8  /  17
# 	Stopping threshold met -- exiting after 8 iterations
# Wed Aug  2 20:23:14 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:23:15 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:25:07 2023 Finished embedding

# %%
pretrained_training_output.save('val')
# Out:
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:25:10 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:25:10 2023 Finding Nearest Neighbors
# Wed Aug  2 20:25:10 2023 Building RP forest with 13 trees
# Wed Aug  2 20:25:10 2023 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	 7  /  15
# 	 8  /  15
# 	Stopping threshold met -- exiting after 8 iterations
# Wed Aug  2 20:25:11 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:25:12 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:25:30 2023 Finished embedding

# %%
pretrained_training_output.save('test')
# Out:
# UMAP(random_state=1, verbose=True)
# Wed Aug  2 20:25:31 2023 Construct fuzzy simplicial set
# Wed Aug  2 20:25:31 2023 Finding Nearest Neighbors
# Wed Aug  2 20:25:31 2023 Building RP forest with 14 trees
# Wed Aug  2 20:25:31 2023 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	 7  /  15
# 	Stopping threshold met -- exiting after 7 iterations
# Wed Aug  2 20:25:33 2023 Finished Nearest Neighbor Search
# Wed Aug  2 20:25:33 2023 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# Wed Aug  2 20:25:54 2023 Finished embedding

# %%
px.scatter(
          analysis, x="x", y="y",
          color='truth',
          hover_data = ['truth'],
          color_discrete_sequence=px.colors.qualitative.Light24_r,
          template='ggplot2')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="6e52f880-d0f8-45e8-8ec1-331af12bf3de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e52f880-d0f8-45e8-8ec1-331af12bf3de")) {                    Plotly.newPlot(                        "6e52f880-d0f8-45e8-8ec1-331af12bf3de",                        [{"customdata":[["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS]"],["[CLS] ...
