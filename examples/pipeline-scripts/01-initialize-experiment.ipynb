# %%
if 'google.colab' in str(get_ipython()):
    from google.colab import userdata
    access_token = userdata.get('DEFORMER_TOKEN')
    # !pip install git+https://$access_token@github.com/ay94/deformer-extractor.git@main
# Out:
# Collecting git+https://****@github.com/ay94/deformer-extractor.git@main
#   Cloning https://****@github.com/ay94/deformer-extractor.git (to revision main) to /tmp/pip-req-build-l3l4x8si
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/ay94/deformer-extractor.git' /tmp/pip-req-build-l3l4x8si
#   Resolved https://****@github.com/ay94/deformer-extractor.git to commit a44060b0cb952793aefcaf95b2ff6aad5e760bc2
#   Preparing metadata (setup.py) ... done
# Collecting appnope (from experiment_utils==1.0.0)
#   Downloading appnope-0.1.4-py2.py3-none-any.whl.metadata (908 bytes)
# Collecting arabert (from experiment_utils==1.0.0)
#   Downloading arabert-1.0.1-py3-none-any.whl.metadata (16 kB)
# Collecting asttokens (from experiment_utils==1.0.0)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (2024.7.4)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (3.3.2)
# Collecting comm (from experiment_utils==1.0.0)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (1.6.6)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (4.4.2)
# Collecting emoji (from experiment_utils==1.0.0)
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (1.2.2)
# Collecting executing (from experiment_utils==1.0.0)
#   Downloading executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting Farasa (from experiment_utils==1.0.0)
#   Downloading Farasa-0.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting farasapy (from experiment_utils==1.0.0)
#   Downloading farasapy-0.0.14-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (3.15.4)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (0.23.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (3.7)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (8.2.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (5.5.6)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (7.34.0)
# Collecting jedi (from experiment_utils==1.0.0)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (1.4.2)
# Requirement already satisfied: jupyter_client in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (6.1.12)
# Requirement already satisfied: jupyter_core in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (5.7.2)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (0.43.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (1.6.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (2.1.4)
# Requirement already satisfied: parso in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (0.8.4)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (4.9.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (4.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (5.15.0)
# Requirement already satisfied: prompt_toolkit in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (3.0.47)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (5.9.5)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (0.7.0)
# Collecting pure-eval (from experiment_utils==1.0.0)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting PyArabic (from experiment_utils==1.0.0)
#   Downloading PyArabic-0.6.15-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (2.16.1)
# Collecting pynndescent (from experiment_utils==1.0.0)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (2024.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (6.0.2)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (24.0.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (2.32.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (1.13.1)
# Collecting seqeval (from experiment_utils==1.0.0)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (1.16.0)
# Collecting stack-data (from experiment_utils==1.0.0)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (9.0.0)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (3.5.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (0.19.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (2.3.1+cu121)
# Requirement already satisfied: tornado in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (6.3.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (4.66.5)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (5.7.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (4.42.4)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (4.12.2)
# Collecting umap-learn (from experiment_utils==1.0.0)
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (2.0.7)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (0.2.13)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (3.19.2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (7.7.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.0) (7.4.4)
# Collecting datasets (from experiment_utils==1.0.0)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->experiment_utils==1.0.0) (2024.6.1)
# Collecting emoji (from experiment_utils==1.0.0)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyarrow>=15.0.0 (from datasets->experiment_utils==1.0.0)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->experiment_utils==1.0.0)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->experiment_utils==1.0.0)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->experiment_utils==1.0.0)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->experiment_utils==1.0.0) (3.10.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->experiment_utils==1.0.0) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->experiment_utils==1.0.0) (71.0.4)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->experiment_utils==1.0.0) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->experiment_utils==1.0.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->experiment_utils==1.0.0) (3.6.8)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->experiment_utils==1.0.0) (3.0.11)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->experiment_utils==1.0.0) (2024.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.10/dist-packages (from pytest->experiment_utils==1.0.0) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from pytest->experiment_utils==1.0.0) (1.5.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pytest->experiment_utils==1.0.0) (2.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->experiment_utils==1.0.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->experiment_utils==1.0.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->experiment_utils==1.0.0) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->experiment_utils==1.0.0)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->experiment_utils==1.0.0) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->experiment_utils==1.0.0)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->experiment_utils==1.0.0) (0.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.0) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.0) (4.0.3)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (6.5.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->experiment_utils==1.0.0) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->experiment_utils==1.0.0) (1.3.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (1.1.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.20.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.0) (1.3.1)
# Downloading appnope-0.1.4-py2.py3-none-any.whl (4.3 kB)
# Downloading arabert-1.0.1-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 6.6 MB/s eta 0:00:00
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 14.9 MB/s eta 0:00:00
# Downloading executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Downloading Farasa-0.0.1-py2.py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 17.8 MB/s eta 0:00:00
# Downloading farasapy-0.0.14-py3-none-any.whl (11 kB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 7.9 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.8 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 2.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.5 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 10.2 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.8 MB/s eta 0:00:00
# Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.4 MB/s eta 0:00:00
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Building wheels for collected packages: experiment_utils, emoji, seqeval
#   Building wheel for experiment_utils (setup.py) ... done
#   Created wheel for experiment_utils: filename=experiment_utils-1.0.0-py3-none-any.whl size=41389 sha256=506e1b7359015fdc112ead9f48e183e8160fd9ac8c6c576deaa308529b677df0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wkefei2v/wheels/f8/36/f4/8857e4d024732b3fefd98f3ea53a402fb0f5a35ca799305f55
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186456 sha256=31443b9370f5ec7424dcd55bf707af90d1f5a686f01951c708f6d94118beffae
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=dcf6437cc113a6a41f08a2c5b8e5cc34b9bed8f47cdac8a706ed629620a0e7fd
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built experiment_utils emoji seqeval
# Installing collected packages: pure-eval, emoji, xxhash, pyarrow, PyArabic, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, jedi, Farasa, executing, dill, comm, asttokens, appnope, stack-data, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, farasapy, seqeval, pynndescent, nvidia-cusolver-cu12, arabert, umap-learn, datasets, experiment_utils
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed Farasa-0.0.1 PyArabic-0.6.15 appnope-0.1.4 arabert-1.0.1 asttokens-2.4.1 comm-0.2.2 datasets-2.21.0 dill-0.3.8 emoji-1.4.2 executing-2.0.1 experiment_utils-1.0.0 farasapy-0.0.14 jedi-0.19.1 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 pure-eval-0.2.3 pyarrow-17.0.0 pynndescent-0.5.13 seqeval-1.2.2 stack-data-0.6.3 umap-learn-0.5.6 xxhash-3.4.1

# %%
from experiment_utils import env_setup
from experiment_utils.utils import  FileHandler
from experiment_utils.pipelines import  ExperimentInitializer

# %%
base_folder = env_setup.init(drive_folder='My Drive', drive_mount='ahmed')
# Out:
# Mounted at /content/ahmed

# %%
experiment_base_folder = base_folder / 'Final Year Experiments/Thesis-Experiments/Experiments/test_merge'
experiments_fh = FileHandler(experiment_base_folder.parent)
experiments = experiments_fh.load_yaml('experiments.yaml')

# %%
variant = "ANERCorp_CamelLab_arabertv02"
variant_data = experiments.get(variant)
# # dataset_name = "conll2003"
# # model_name = "bert"
# # model_path = "bert-base-cased"
# # variant = "conll2003_bert"

# dataset_name = "ANERCorp_CamelLab"
# model_name = "arabertv02"
# model_path = "aubmindlab/bert-base-arabertv02"
# variant = "ANERCorp_CamelLab_arabertv02"

experiment_config = {
    "experiment_name": "DashboardTest",
    "corpora_path": "ExperimentData",
    "variant": variant,
    "dataset_name": variant_data['dataset_name'],
    "model_name": variant_data['model_name'],
    "model_path": variant_data['model_path'],
    "results_config": "results_config.yaml",
    "extraction_config": "extraction_config.yaml",
    "fine_tuning_config": "fine_tuning_config.yaml"
}


extraction_config = {
    "fine_tuning": {
        "args": {
            "train_batch_size": 16,
            "test_batch_size": 8,
            "shuffle": True,
            "num_workers": 2,
            "epochs": 4,
            "splits": 4,
            "learning_rate": 5e-5,
            "warmup_ratio": 0.1,
            "max_grad_norm": 1.0,
            "accumulation_steps": 1,
            "logging_step": 50
        },
        "model": {
            "model_path": variant_data['model_path'],
            "dropout_rate": 0.1,
            "enable_attentions": False,
            "enable_hidden_states": False,
            "initialize_output_layer": False
        },
        "evaluation": {
            "scheme": None,
            "mode": None
        }
    },
    "extraction": {
        "tokenization": {
            "tokenizer_path": variant_data['model_path'],
            "preprocessor_path": None,
            "max_seq_len": 256,
            "strategy": {
                "type": "core",
                "index": 0,
                "schema": None
            }
        },
        "umap": {
            "n_neighbors": 15,
            "min_dist": 0.1,
            "metric": "cosine",
            "random_state": 1,
            "verbose": True,
            "normalize_embeddings": False
        },
        "clustering": {
            "init_method": "k-means++",
            "n_init": 10,
            "random_state": 1,
            "n_clusters": [3, 4, 9],
            "n_clusters_map": {
                3: "boundary_clusters",
                4: "entity_clusters",
                9: "token_clusters"
            },
            "silhouette_metric": "cosine",
            "norm": "l2"
        }
    }
}

results_config = {
    "results_dir": "extractions",
    "analysis_data": {
        "folder": "analysis",
        "filename": "analysis_data",
        "format": "json"
    },
    "entity_report": {
        "folder": "results",
        "filename": "entity_report",
        "format": "json"
    },
    "token_report": {
        "folder": "results",
        "filename": "token_report",
        "format": "json"
    },
    "results": {
        "folder": "results",
        "filename": "results",
        "format": "json"
    },
    "kmeans_results": {
        "folder": "results",
        "filename": "kmeans_results",
        "format": "json"
    },
    "entity_confusion_data": {
        "folder": "results",
        "filename": "entity_confusion_data",
        "format": "json"
    },
    "attention_weights_similarity": {
        "folder": "matrices",
        "filename": "attention_weights_similarity",
        "format": "json"
    },
    "centroids_avg_similarity_matrix": {
        "folder": "matrices",
        "filename": "centroids_avg_similarity_matrix",
        "format": "json"
    },
    "attention_similarity_matrix": {
        "folder": "matrices",
        "filename": "attention_similarity_matrix",
        "format": "json"
    },
    "train_df": {
        "folder": "analysis",
        "filename": "train_df",
        "format": "json"
    },
}

fine_tuning_config = {
    "save_dir": "fine_tuning",  # Base directory for saving outputs
    "metrics": {
        "folder": "metrics",
        "filename": "evaluation_metrics",
        "format": "json"
    },
    "model": {
        "state_dict": {
            "filename": "model_state_dict",
            "format": "pth"
        },
        "binary": {
            "filename": "model_binary",
            "format": "bin"
        }
    },

}

# %%
# setup experiment folder
manager = ExperimentInitializer(experiment_base_folder, experiment_config, extraction_config, results_config, fine_tuning_config)
manager.setup_experiment()

# %%
drive.flush_and_unmount()
