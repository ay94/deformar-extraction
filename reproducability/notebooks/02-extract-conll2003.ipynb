# %%
if 'google.colab' in str(get_ipython()):
    from google.colab import userdata
    access_token = userdata.get('DEFORMER_TOKEN')
    # !pip install git+https://$access_token@github.com/ay94/deformer-extractor.git@v1.0.3
# Out:
# Collecting git+https://****@github.com/ay94/deformer-extractor.git@v1.0.3
#   Cloning https://****@github.com/ay94/deformer-extractor.git (to revision v1.0.3) to /tmp/pip-req-build-56klk_2t
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/ay94/deformer-extractor.git' /tmp/pip-req-build-56klk_2t
#   Resolved https://****@github.com/ay94/deformer-extractor.git to commit e5f1d5d2098e24cb3918faf6b0c1e06df1a6117a
#   Preparing metadata (setup.py) ... done
# Collecting appnope (from experiment_utils==1.0.3)
#   Downloading appnope-0.1.4-py2.py3-none-any.whl.metadata (908 bytes)
# Collecting arabert (from experiment_utils==1.0.3)
#   Downloading arabert-1.0.1-py3-none-any.whl.metadata (16 kB)
# Collecting asttokens (from experiment_utils==1.0.3)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (2024.7.4)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (3.3.2)
# Collecting comm (from experiment_utils==1.0.3)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: debugpy in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (1.6.6)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (4.4.2)
# Collecting emoji (from experiment_utils==1.0.3)
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (1.2.2)
# Collecting executing (from experiment_utils==1.0.3)
#   Downloading executing-2.0.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting Farasa (from experiment_utils==1.0.3)
#   Downloading Farasa-0.0.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting farasapy (from experiment_utils==1.0.3)
#   Downloading farasapy-0.0.14-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (3.15.4)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (0.23.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (3.8)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (8.4.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (5.5.6)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (7.34.0)
# Collecting jedi (from experiment_utils==1.0.3)
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (1.4.2)
# Requirement already satisfied: jupyter_client in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (6.1.12)
# Requirement already satisfied: jupyter_core in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (5.7.2)
# Requirement already satisfied: llvmlite in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (0.43.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (1.6.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (24.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (2.1.4)
# Requirement already satisfied: parso in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (0.8.4)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (4.9.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (4.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (5.15.0)
# Requirement already satisfied: prompt_toolkit in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (3.0.47)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (5.9.5)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (0.7.0)
# Collecting pure-eval (from experiment_utils==1.0.3)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting PyArabic (from experiment_utils==1.0.3)
#   Downloading PyArabic-0.6.15-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Pygments in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (2.16.1)
# Collecting pynndescent (from experiment_utils==1.0.3)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (2024.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (6.0.2)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (24.0.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (2.32.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (1.3.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (1.13.1)
# Collecting seqeval (from experiment_utils==1.0.3)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (1.16.0)
# Collecting stack-data (from experiment_utils==1.0.3)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (9.0.0)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (3.5.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (0.19.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (2.4.0+cu121)
# Requirement already satisfied: tornado in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (6.3.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (4.66.5)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (5.7.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (4.42.4)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (4.12.2)
# Collecting umap-learn (from experiment_utils==1.0.3)
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (2.0.7)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (0.2.13)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (3.20.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (7.7.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.10/dist-packages (from experiment_utils==1.0.3) (7.4.4)
# Collecting datasets (from experiment_utils==1.0.3)
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->experiment_utils==1.0.3) (2024.6.1)
# Collecting emoji (from experiment_utils==1.0.3)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyarrow>=15.0.0 (from datasets->experiment_utils==1.0.3)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->experiment_utils==1.0.3)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets->experiment_utils==1.0.3)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->experiment_utils==1.0.3)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->experiment_utils==1.0.3) (3.10.5)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->experiment_utils==1.0.3) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->experiment_utils==1.0.3) (71.0.4)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->experiment_utils==1.0.3) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->experiment_utils==1.0.3) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->experiment_utils==1.0.3) (3.6.8)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->experiment_utils==1.0.3) (3.0.13)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->experiment_utils==1.0.3) (2024.1)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.10/dist-packages (from pytest->experiment_utils==1.0.3) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from pytest->experiment_utils==1.0.3) (1.5.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pytest->experiment_utils==1.0.3) (2.0.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->experiment_utils==1.0.3) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->experiment_utils==1.0.3) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->experiment_utils==1.0.3) (3.1.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->experiment_utils==1.0.3) (0.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.3) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.3) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.3) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.3) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.3) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.3) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->experiment_utils==1.0.3) (4.0.3)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (6.5.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->experiment_utils==1.0.3) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->experiment_utils==1.0.3) (1.3.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (1.1.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.20.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->experiment_utils==1.0.3) (1.3.1)
# Downloading appnope-0.1.4-py2.py3-none-any.whl (4.3 kB)
# Downloading arabert-1.0.1-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.9 MB/s eta 0:00:00
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 36.9 MB/s eta 0:00:00
# Downloading executing-2.0.1-py2.py3-none-any.whl (24 kB)
# Downloading Farasa-0.0.1-py2.py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 84.1 MB/s eta 0:00:00
# Downloading farasapy-0.0.14-py3-none-any.whl (11 kB)
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 15.3 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 6.8 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 10.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.3 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 29.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.1 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.2 MB/s eta 0:00:00
# Building wheels for collected packages: experiment_utils, emoji, seqeval
#   Building wheel for experiment_utils (setup.py) ... done
#   Created wheel for experiment_utils: filename=experiment_utils-1.0.3-py3-none-any.whl size=42008 sha256=9dca8d11baf6a894b8923bfeacf09c3e3d7eed5208d02d1172ad25400fa286cc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vt4f_wjw/wheels/6a/05/8b/1b650d532fe62c6d66711af984d1582fa9e4c5bf994468eaa4
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186456 sha256=d2d1293816a6c1c759fbc5c3b06a14084ffee1309b5243d07429c9a4817780d3
#   Stored in directory: /root/.cache/pip/wheels/10/f0/fd/4813b1177405693e8da9cdea839f0fb64fde161380e058c827
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16161 sha256=9d3aa8bb58977b5fad886529109bf1eb3e1d84e82db19a8eb221cb2440ad06ed
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built experiment_utils emoji seqeval
# Installing collected packages: pure-eval, emoji, xxhash, pyarrow, PyArabic, jedi, Farasa, executing, dill, comm, asttokens, appnope, stack-data, multiprocess, farasapy, seqeval, pynndescent, arabert, umap-learn, datasets, experiment_utils
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed Farasa-0.0.1 PyArabic-0.6.15 appnope-0.1.4 arabert-1.0.1 asttokens-2.4.1 comm-0.2.2 datasets-2.21.0 dill-0.3.8 emoji-1.4.2 executing-2.0.1 experiment_utils-1.0.3 farasapy-0.0.14 jedi-0.19.1 multiprocess-0.70.16 pure-eval-0.2.3 pyarrow-17.0.0 pynndescent-0.5.13 seqeval-1.2.2 stack-data-0.6.3 umap-learn-0.5.6 xxhash-3.5.0

# %%
from experiment_utils import env_setup
from experiment_utils.pipelines import DataExtractionPhase

# %%
base_folder = env_setup.init('My Drive', drive_mount='drive')
# Out:
# Mounted at /content/drive

# %%
experiment_base_folder = base_folder / 'Final Year Experiments/Thesis-Experiments/Experiments'

# %%
variant = "conll2003_bert"
experiment_name = "BaseLineExperiment"
data_extractor = DataExtractionPhase(experiment_base_folder, experiment_name, variant)
# Out:
# INFO:root:Experiment manager set up successfully.
# INFO:root:Extraction manager set up successfully.
# INFO:root:Results manager set up successfully.
# INFO:root:Fine Tuning manager set up successfully.
# INFO:root:Tokenization Config validated successfully
# INFO:root:Dataset manager set up successfully.

# %%
data_extractor.run_fine_tuning_phase()
# Out:
# INFO:root:Model Config validated successfully
# INFO:root:Training Config validated successfully
# INFO:root:Evaluation Config validated successfully
# INFO:root:Loading BERT Model from: bert-base-cased
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# INFO:root:Model bert-base-cased loaded and sent to cuda
# INFO:root:Loading Tokenizer: bert-base-cased, lower_case: False
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# INFO:root:Loading Tokenizer: bert-base-cased, lower_case: False
# INFO:root:Loading Tokenizer: bert-base-cased, lower_case: False
# INFO:root:num_train_steps: 3510
# INFO:root:Trainer set up successfully.
# INFO:root:Standard
# INFO:root:Start Training Epoch: 1
# Training:   0%|          | 0/878 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Start Evaluation
# INFO:root:Validation Split is Available
# Evaluation:   0%|          | 0/407 [00:00<?, ?it/s]
# INFO:root:Training Loss: 0.24780573987678872 | Eval Loss: 0.05270622587143226
# INFO:root:Epoch completed in 290.1856732368469 s
# INFO:root:
# Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.9256 │   0.9282 │ 0.9265 │ 0.0527 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤═══════╤════════╕
# │   Precision │   Recall │    F1 │   Loss │
# ╞═════════════╪══════════╪═══════╪════════╡
# │      0.9051 │   0.9231 │ 0.914 │ 0.0527 │
# ╘═════════════╧══════════╧═══════╧════════╛
# INFO:root:Start Training Epoch: 2
# Training:   0%|          | 0/878 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Start Evaluation
# INFO:root:Validation Split is Available
# Evaluation:   0%|          | 0/407 [00:00<?, ?it/s]
# INFO:root:Training Loss: 0.043140148659078816 | Eval Loss: 0.04042940507506344
# INFO:root:Epoch completed in 291.3544034957886 s
# INFO:root:
# Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.9516 │   0.9394 │ 0.9453 │ 0.0404 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.9377 │   0.9419 │ 0.9398 │ 0.0404 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:Start Training Epoch: 3
# Training:   0%|          | 0/878 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Start Evaluation
# INFO:root:Validation Split is Available
# Evaluation:   0%|          | 0/407 [00:00<?, ?it/s]
# INFO:root:Training Loss: 0.016698296745238796 | Eval Loss: 0.03992912962267442
# INFO:root:Epoch completed in 290.31322598457336 s
# INFO:root:
# Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.9574 │   0.9477 │ 0.9524 │ 0.0399 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.9428 │   0.9495 │ 0.9462 │ 0.0399 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:Start Training Epoch: 4
# Training:   0%|          | 0/878 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Start Evaluation
# INFO:root:Validation Split is Available
# Evaluation:   0%|          | 0/407 [00:00<?, ?it/s]
# INFO:root:Training Loss: 0.006712808263332518 | Eval Loss: 0.04281624212730434
# INFO:root:Epoch completed in 290.39150190353394 s
# INFO:root:
# Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.9556 │   0.9515 │ 0.9535 │ 0.0428 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.9448 │   0.9539 │ 0.9493 │ 0.0428 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:Final Evaluation on Test Set
# Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Final Test Loss: 0.13497933373080034
# INFO:root:
# Final Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8945 │   0.9156 │ 0.9047 │  0.135 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Final Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.9058 │   0.9193 │ 0.9125 │  0.135 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:Fine-tuning completed.
# INFO:root:Saving Fine Tuning Results in /content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/conll2003_bert/fine_tuning
# INFO:root:Fine-tuning results saved successfully.
# INFO:root:Fine-tuning phase completed successfully.

# %%
data_extractor.run_extraction_phase()
# Out:
# /usr/local/lib/python3.10/dist-packages/experiment_utils/utils.py:109: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(file_path)
# INFO:root:Setting output_attentions to enabled.
# INFO:root:Extractors setup.
# INFO:root:Loading pretrained model from: bert-base-cased
# INFO:root:Generating model outputs
# INFO:root:Training Config validated successfully
# INFO:root:Processing train Split
# INFO:root:Loading Tokenizer: bert-base-cased, lower_case: False
#   0%|          | 0/878 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# BertSdpaSelfAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support non-absolute `position_embedding_type` or `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# INFO:root:Processing validation Split
# INFO:root:Loading Tokenizer: bert-base-cased, lower_case: False
#   0%|          | 0/407 [00:00<?, ?it/s]
# INFO:root:Processing test Split
# INFO:root:Loading Tokenizer: bert-base-cased, lower_case: False
#   0%|          | 0/432 [00:00<?, ?it/s]
# INFO:root:Generating pretrained model outputs for split: test
# INFO:root:Training Config validated successfully
# INFO:root:Loading Tokenizer: bert-base-cased, lower_case: False
#   0%|          | 0/432 [00:00<?, ?it/s]
# INFO:root:Generating tokenization outputs
# INFO:root:Tokenization Config validated successfully
# INFO:root:Loading Tokenizer bert-base-cased, Lower Case False
# INFO:root:Processing train split
#   0%|          | 0/14041 [00:00<?, ?it/s]
# INFO:root:Extracting train subwords
#   0%|          | 0/14041 [00:00<?, ?it/s]
# INFO:root:Processing validation split
#   0%|          | 0/3250 [00:00<?, ?it/s]
# INFO:root:Processing test split
#   0%|          | 0/3453 [00:00<?, ?it/s]
# INFO:root:UMAP Config validated successfully
# INFO:root:Analysis extraction pipeline initialized successfully.
# INFO:root:Extracting model features...
# INFO:root:Extracting tokenization features...
# INFO:root:Aligning labels...
# INFO:root:Applying UMAP...
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(angular_rp_forest=True, metric='cosine', n_jobs=1, random_state=1, verbose=True)
# Sat Aug 31 12:06:33 2024 Construct fuzzy simplicial set
# Sat Aug 31 12:06:33 2024 Finding Nearest Neighbors
# Sat Aug 31 12:06:33 2024 Building RP forest with 18 trees
# Sat Aug 31 12:06:43 2024 NN descent for 16 iterations
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# 	 4  /  16
# 	 5  /  16
# 	Stopping threshold met -- exiting after 5 iterations
# Sat Aug 31 12:07:07 2024 Finished Nearest Neighbor Search
# Sat Aug 31 12:07:10 2024 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# INFO:root:Extracting model features...
# INFO:root:Extracting tokenization features...
# INFO:root:Applying UMAP...
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Sat Aug 31 12:08:12 2024 Finished embedding
# UMAP(angular_rp_forest=True, metric='cosine', n_jobs=1, random_state=1, verbose=True)
# Sat Aug 31 12:08:13 2024 Construct fuzzy simplicial set
# Sat Aug 31 12:08:13 2024 Finding Nearest Neighbors
# Sat Aug 31 12:08:13 2024 Building RP forest with 18 trees
# Sat Aug 31 12:08:19 2024 NN descent for 16 iterations
# 	 1  /  16
# 	 2  /  16
# 	 3  /  16
# 	 4  /  16
# 	 5  /  16
# 	 6  /  16
# 	Stopping threshold met -- exiting after 6 iterations
# Sat Aug 31 12:08:29 2024 Finished Nearest Neighbor Search
# Sat Aug 31 12:08:29 2024 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Aug 31 12:09:29 2024 Finished embedding
# INFO:root:Clustering Config validated successfully
# INFO:root:Calculating Silhouette Score
# INFO:root:Processing K=3
# INFO:root:Processing K=4
# INFO:root:Processing K=9
# INFO:root:Calculating Centorid Average Similarity Matrix
# INFO:root:Annotating all...
# INFO:root:Annotating consistency...
# Extract Subwords:   0%|          | 0/11243 [00:00<?, ?it/s]
# Calculate Consistency:   0%|          | 0/70367 [00:00<?, ?it/s]
# INFO:root:Annotating token entropy...
# INFO:root:Annotating word entropy...
# INFO:root:Annotating entity...
# INFO:root:Annotating error types...
# INFO:root:Annotating prediction entropy...
# INFO:root:Annotating pretrained coordinates...
# INFO:root:Analysis workflow execution time: 237.77924585342407 seconds
# INFO:root:Computing attention similarities
# Computing attention similarities:   0%|          | 0/3453 [00:00<?, ?it/s]
# INFO:root:Comparing weights
# INFO:root:Data extraction completed successfully.
# INFO:root:Saving Extraction Results in /content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/conll2003_bert/extractions
# INFO:root:Extracted results saved successfully.
# INFO:root:Extraction phase completed successfully.

# %%
data_extractor.generate_train_df()
# Out:
# INFO:root:Extracting model features...
# INFO:root:Applying UMAP...
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# UMAP(angular_rp_forest=True, metric='cosine', n_jobs=1, random_state=1, verbose=True)
# Sat Aug 31 12:11:56 2024 Construct fuzzy simplicial set
# Sat Aug 31 12:11:56 2024 Finding Nearest Neighbors
# Sat Aug 31 12:11:56 2024 Building RP forest with 32 trees
# Sat Aug 31 12:12:52 2024 NN descent for 18 iterations
# 	 1  /  18
# 	 2  /  18
# 	 3  /  18
# 	 4  /  18
# 	 5  /  18
# 	Stopping threshold met -- exiting after 5 iterations
# Sat Aug 31 12:13:43 2024 Finished Nearest Neighbor Search
# Sat Aug 31 12:13:45 2024 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Aug 31 12:31:25 2024 Finished embedding

# %%
import plotly.express as px

# %%
df = data_extractor.analysis_extraction_pipeline.analysis_data

# %%
px.scatter(df, x='x', y='y', color='true_labels')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
data_extractor.experiment_manager.variant_dir
# Out:
# PosixPath('/content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/conll2003_bert')

# %%
env_setup.save_environment_info(data_extractor.experiment_manager.variant_dir)
# Out:
# INFO:root:Python version saved to /content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/conll2003_bert/python_version.txt
# INFO:root:Installed packages saved to /content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/conll2003_bert/requirements.txt
