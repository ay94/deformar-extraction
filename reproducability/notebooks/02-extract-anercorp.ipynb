# %%
if 'google.colab' in str(get_ipython()):
    from google.colab import userdata
    access_token = userdata.get('DEFORMER_TOKEN')
    # !pip install git+https://$access_token@github.com/ay94/deformer-extractor.git@v1.0.3

# %%
from experiment_utils import env_setup
from experiment_utils.pipelines import DataExtractionPhase
# Out:
# 2025-04-18 01:04:15 - INFO - PyTorch version 1.13.1 available.

# %%
base_folder = env_setup.init('My Drive', drive_mount='drive')
# Out:
# 2025-04-18 01:04:31 - WARNING - Resolved path does not exist, checking alternative paths: /Users/ay227/Library/CloudStorage/GoogleDrive-ahmed.younes.sam@gmail.com/My Drive/Final Year Experiments/Thesis-Experiments/scripts/base_line/My Drive
# 2025-04-18 01:04:31 - INFO - Found Google Drive directory for account ahmed.younes.sam@gmail.com: /Users/ay227/Library/CloudStorage/GoogleDrive-ahmed.younes.sam@gmail.com

# %%
experiment_base_folder = base_folder / 'Final Year Experiments/Thesis-Experiments/Experiments'

# %%
variant = "ANERCorp_CamelLab_arabertv02"
experiment_name = "BaseLineExperiment"
data_extractor = DataExtractionPhase(experiment_base_folder, experiment_name, variant)
# Out:
# 2025-04-18 01:05:52 - INFO - Experiment manager set up successfully.
# 2025-04-18 01:05:52 - INFO - Extraction manager set up successfully.
# 2025-04-18 01:05:52 - INFO - Results manager set up successfully.
# 2025-04-18 01:05:52 - INFO - Fine Tuning manager set up successfully.
# 2025-04-18 01:05:52 - INFO - Tokenization Config validated successfully
# 2025-04-18 01:05:52 - INFO - Dataset manager set up successfully.

# %%
data_extractor.run_fine_tuning_phase()
# Out:
# INFO:root:Model Config validated successfully
# INFO:root:Training Config validated successfully
# INFO:root:Evaluation Config validated successfully
# INFO:root:Loading BERT Model from: aubmindlab/bert-base-arabertv02
# config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/543M [00:00<?, ?B/s]
# INFO:root:Model aubmindlab/bert-base-arabertv02 loaded and sent to cuda
# INFO:root:Loading Preprocessor: aubmindlab/bert-base-arabertv02
# INFO:root:Loading Tokenizer: aubmindlab/bert-base-arabertv02, lower_case: False
# tokenizer_config.json:   0%|          | 0.00/381 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/825k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.64M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# INFO:root:Loading Preprocessor: aubmindlab/bert-base-arabertv02
# INFO:root:Loading Tokenizer: aubmindlab/bert-base-arabertv02, lower_case: False
# ERROR:root:The validation Split Doesn't Exist
# INFO:root:num_train_steps: 1037
# INFO:root:Trainer set up successfully.
# INFO:root:Standard
# INFO:root:Start Training Epoch: 1
# Training:   0%|          | 0/260 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Start Evaluation
# INFO:root:Test Split is Used for Evaluation
# Evaluation:   0%|          | 0/121 [00:00<?, ?it/s]
# INFO:root:Training Loss: 0.28364024496135803 | Eval Loss: 0.14099336623729877
# INFO:root:Epoch completed in 87.89945840835571 s
# INFO:root:
# Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8276 │   0.7909 │ 0.8058 │  0.141 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤═══════╤════════╕
# │   Precision │   Recall │    F1 │   Loss │
# ╞═════════════╪══════════╪═══════╪════════╡
# │      0.8077 │   0.8003 │ 0.804 │  0.141 │
# ╘═════════════╧══════════╧═══════╧════════╛
# INFO:root:Start Training Epoch: 2
# Training:   0%|          | 0/260 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Start Evaluation
# INFO:root:Test Split is Used for Evaluation
# Evaluation:   0%|          | 0/121 [00:00<?, ?it/s]
# INFO:root:Training Loss: 0.05160370701744866 | Eval Loss: 0.15033338736542615
# INFO:root:Epoch completed in 90.63665819168091 s
# INFO:root:
# Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8589 │   0.7862 │ 0.8178 │ 0.1503 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8456 │   0.7845 │ 0.8139 │ 0.1503 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:Start Training Epoch: 3
# Training:   0%|          | 0/260 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Start Evaluation
# INFO:root:Test Split is Used for Evaluation
# Evaluation:   0%|          | 0/121 [00:00<?, ?it/s]
# INFO:root:Training Loss: 0.028084219005093194 | Eval Loss: 0.16459421203221572
# INFO:root:Epoch completed in 90.41417670249939 s
# INFO:root:
# Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8701 │   0.8081 │ 0.8337 │ 0.1646 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8504 │   0.8191 │ 0.8344 │ 0.1646 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:Start Training Epoch: 4
# Training:   0%|          | 0/260 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Start Evaluation
# INFO:root:Test Split is Used for Evaluation
# Evaluation:   0%|          | 0/121 [00:00<?, ?it/s]
# INFO:root:Training Loss: 0.017335683984744648 | Eval Loss: 0.16454549607713054
# INFO:root:Epoch completed in 90.29628205299377 s
# INFO:root:
# Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8649 │   0.7934 │ 0.8205 │ 0.1645 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8483 │   0.8178 │ 0.8327 │ 0.1645 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:Final Evaluation on Test Set
# Evaluation:   0%|          | 0/121 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# INFO:root:Final Test Loss: 0.16454549607713054
# INFO:root:
# Final Token-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8649 │   0.7934 │ 0.8205 │ 0.1645 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:
# Final Entity-Level Evaluation Metrics:
# INFO:root:
# ╒═════════════╤══════════╤════════╤════════╕
# │   Precision │   Recall │     F1 │   Loss │
# ╞═════════════╪══════════╪════════╪════════╡
# │      0.8483 │   0.8178 │ 0.8327 │ 0.1645 │
# ╘═════════════╧══════════╧════════╧════════╛
# INFO:root:Fine-tuning completed.
# INFO:root:Saving Fine Tuning Results in /content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/ANERCorp_CamelLab_arabertv02/fine_tuning
# INFO:root:Fine-tuning results saved successfully.
# INFO:root:Fine-tuning phase completed successfully.

# %%
data_extractor.run_extraction_phase()
# Out:
# /usr/local/lib/python3.10/dist-packages/experiment_utils/utils.py:109: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(file_path)
# INFO:root:Setting output_attentions to enabled.
# INFO:root:Extractors setup.
# INFO:root:Loading pretrained model from: aubmindlab/bert-base-arabertv02
# INFO:root:Generating model outputs
# INFO:root:Training Config validated successfully
# INFO:root:Processing train Split
# INFO:root:Loading Preprocessor: aubmindlab/bert-base-arabertv02
# INFO:root:Loading Tokenizer: aubmindlab/bert-base-arabertv02, lower_case: False
#   0%|          | 0/260 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# BertSdpaSelfAttention is used but `torch.nn.functional.scaled_dot_product_attention` does not support non-absolute `position_embedding_type` or `output_attentions=True` or `head_mask`. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.
# INFO:root:Processing test Split
# INFO:root:Loading Preprocessor: aubmindlab/bert-base-arabertv02
# INFO:root:Loading Tokenizer: aubmindlab/bert-base-arabertv02, lower_case: False
#   0%|          | 0/121 [00:00<?, ?it/s]
# INFO:root:Generating pretrained model outputs for split: test
# INFO:root:Training Config validated successfully
# INFO:root:Loading Preprocessor: aubmindlab/bert-base-arabertv02
# INFO:root:Loading Tokenizer: aubmindlab/bert-base-arabertv02, lower_case: False
#   0%|          | 0/121 [00:00<?, ?it/s]
# INFO:root:Generating tokenization outputs
# INFO:root:Tokenization Config validated successfully
# INFO:root:Loading Tokenizer aubmindlab/bert-base-arabertv02, Lower Case False
# INFO:root:Loading Preprocessor aubmindlab/bert-base-arabertv02
# INFO:root:Processing train split
#   0%|          | 0/4149 [00:00<?, ?it/s]
# INFO:root:Extracting train subwords
#   0%|          | 0/4149 [00:00<?, ?it/s]
# INFO:root:Processing test split
#   0%|          | 0/961 [00:00<?, ?it/s]
# INFO:root:UMAP Config validated successfully
# INFO:root:Analysis extraction pipeline initialized successfully.
# INFO:root:Extracting model features...
# INFO:root:Extracting tokenization features...
# INFO:root:Aligning labels...
# INFO:root:Applying UMAP...
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(angular_rp_forest=True, metric='cosine', n_jobs=1, random_state=1, verbose=True)
# Sat Aug 31 11:10:15 2024 Construct fuzzy simplicial set
# Sat Aug 31 11:10:15 2024 Finding Nearest Neighbors
# Sat Aug 31 11:10:15 2024 Building RP forest with 14 trees
# Sat Aug 31 11:10:21 2024 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	Stopping threshold met -- exiting after 6 iterations
# Sat Aug 31 11:10:39 2024 Finished Nearest Neighbor Search
# Sat Aug 31 11:10:42 2024 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Aug 31 11:11:04 2024 Finished embedding
# INFO:root:Extracting model features...
# INFO:root:Extracting tokenization features...
# INFO:root:Applying UMAP...
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# UMAP(angular_rp_forest=True, metric='cosine', n_jobs=1, random_state=1, verbose=True)
# Sat Aug 31 11:11:05 2024 Construct fuzzy simplicial set
# Sat Aug 31 11:11:05 2024 Finding Nearest Neighbors
# Sat Aug 31 11:11:05 2024 Building RP forest with 14 trees
# Sat Aug 31 11:11:06 2024 NN descent for 15 iterations
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	 7  /  15
# 	Stopping threshold met -- exiting after 7 iterations
# Sat Aug 31 11:11:11 2024 Finished Nearest Neighbor Search
# Sat Aug 31 11:11:11 2024 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Aug 31 11:11:32 2024 Finished embedding
# INFO:root:Clustering Config validated successfully
# INFO:root:Calculating Silhouette Score
# INFO:root:Processing K=3
# INFO:root:Processing K=4
# INFO:root:Processing K=9
# INFO:root:Calculating Centorid Average Similarity Matrix
# INFO:root:Annotating all...
# INFO:root:Annotating consistency...
# Extract Subwords:   0%|          | 0/23049 [00:00<?, ?it/s]
# Calculate Consistency:   0%|          | 0/29711 [00:00<?, ?it/s]
# INFO:root:Annotating token entropy...
# INFO:root:Annotating word entropy...
# INFO:root:Annotating entity...
# INFO:root:Annotating error types...
# INFO:root:Annotating prediction entropy...
# INFO:root:Annotating pretrained coordinates...
# INFO:root:Analysis workflow execution time: 110.70085144042969 seconds
# INFO:root:Computing attention similarities
# Computing attention similarities:   0%|          | 0/961 [00:00<?, ?it/s]
# INFO:root:Comparing weights
# INFO:root:Data extraction completed successfully.
# INFO:root:Saving Extraction Results in /content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/ANERCorp_CamelLab_arabertv02/extractions
# INFO:root:Extracted results saved successfully.
# INFO:root:Extraction phase completed successfully.

# %%
data_extractor.generate_train_df()
# Out:
# INFO:root:Extracting model features...
# INFO:root:Applying UMAP...
# /usr/local/lib/python3.10/dist-packages/umap/umap_.py:1945: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
# UMAP(angular_rp_forest=True, metric='cosine', n_jobs=1, random_state=1, verbose=True)
# Sat Aug 31 11:12:56 2024 Construct fuzzy simplicial set
# Sat Aug 31 11:12:56 2024 Finding Nearest Neighbors
# Sat Aug 31 11:12:56 2024 Building RP forest with 24 trees
# Sat Aug 31 11:13:16 2024 NN descent for 17 iterations
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	 5  /  17
# 	 6  /  17
# 	Stopping threshold met -- exiting after 6 iterations
# Sat Aug 31 11:13:43 2024 Finished Nearest Neighbor Search
# Sat Aug 31 11:13:44 2024 Construct embedding
# Epochs completed:   0%|            0/200 [00:00]
# 	completed  0  /  200 epochs
# 	completed  20  /  200 epochs
# 	completed  40  /  200 epochs
# 	completed  60  /  200 epochs
# 	completed  80  /  200 epochs
# 	completed  100  /  200 epochs
# 	completed  120  /  200 epochs
# 	completed  140  /  200 epochs
# 	completed  160  /  200 epochs
# 	completed  180  /  200 epochs
# Sat Aug 31 11:16:04 2024 Finished embedding

# %%
import plotly.express as px
df=data_extractor.analysis_extraction_pipeline.outputs["analysis_data"]
px.scatter(df, x='x', y='y', color='true_labels')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8e5abc01-6e19-420b-abd3-5bfe5dbbbcfc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e5abc01-6e19-420b-abd3-5bfe5dbbbcfc")) {                    Plotly.newPlot(                        "8e5abc01-6e19-420b-abd3-5bfe5dbbbcfc",                        [{"hovertemplate":"true_labels=[CLS]\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"[CLS]","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"[CLS]","showlegend":true,"x":[-0.8344430327415466,-0.8689651489257812,-0.6827220916748047,-0.893310546875,-0.854665994644165,-0.8659366369247437,-0.8143378496170044,-0.8494794368743896,-0.8957932591438293,-0.9076058268547058,-0.7801682353019714,-0.9149419069290161,-0.7360133528709412,-0.8275853395462036,-0.9262424111366272,-0.8658531904220581,-0.885880172252655,-0.9601033926010132,-0.8972745537757874,-0.9230552315711975,-0.8495714664459229,-0.8971760272979736,-0.9014192819595337,-0.9070265889167786,-0.7789826989173889,-0.6819653511047363,-0.938367486000061,-0.8939201831817627,-0.9140112996101379,-0.7778240442276001,-0.777005136013031,-0.7651833295822144,-0.7883511781692505,-0.6713261604309082,-0.6486704349517822,-0.6844409108161926,-0.469488263130188,-0.8100296854972839,-0.7646524310112,-0.7130224704742432,-0.8604317307472229,-0.8492259979248047,-0.8448183536529541,-0.9655110239982605,-0.8452984094619751,-0.9327951669692993,-0.7644680738449097,-0.9351741075515747,-0.9170294404029846,-0.7734497785568237,-0.6965676546096802,-0.9364317059516907,-0.7091953754425049,-0.8662486672401428,-0.776244580745697,-0.6179370880126953,-0.9259238243103027,-0.9125667214393616,-0.9787234663963318,-0.9140917062759399,-0.838733971118927,-0.6754424571990967,-0.8055630326271057,-0.7964958548545837,-0.8489474058151245,-0.7666013240814209,-0.8775081038475037,-0.8308517336845398,-0.8038409352302551,-0.667269766330719,-0.9366887211799622,-0.8460390567779541,-0.8221188187599182,-0.8906029462814331,-0.7370638251304626,-0.5400210618972778,-0.6126959323883057,-0.8660004138946533,-0.8271110653877258,-0.8840000629425049,-0.8367393612861633,-0.6639655232429504,-0.7648448348045349,-0.8144267201423645,-0.6270638108253479,-0.6745820045471191,-0.7141740322113037,-0.7932689785957336,-0.7786325812339783,-0.42826223373413086,-0.8357418179512024,-0.8387860655784607,-0.7136083841323853,-0.651646614074707,-0.5996918082237244,-0.6957352757453918,-0.6414841413497925,-0.507269561290741,-0.5967105627059937,-0.5971242189407349,-0.646354079246521,-0.6445918679237366,-0.7696335911750793,-0.6337898969650269,-0.8852070569992065,-0.8198912143707275,-0.8040851950645447,-0.5304562449455261,-0.8750235438346863,-0.9566675424575806,-0.4896548390388489,-0.6489543914794922,-0.720568835735321,-0.6975086331367493,-0.9570990204811096,-0.6647070050239563,-0.6511983871459961,-0.737041175365448,-0.8352023959159851,-0.7867537140846252,-0.729893684387207,-0.8793630003929138,-0.7550916075706482,-0.8100996613502502,-0.8483067154884338,-0.8128164410591125,-0.8294965028762817,-0.90611332654953,-0.7731115221977234,-0.5541858077049255,-0.8831601142883301,-0.6547840237617493,-0.6807604432106018,-0.7132160067558289,-0.7064639925956726,-0.6631330847740173,-0.6762053370475769,-0.7089885473251343,-0.7549638152122498,-0.6985265016555786,-0.6719265580177307,-0.6169904470443726,-0.6926635503768921,-0.6485676765441895,-0.6775484681129456,-0.6588718891143799,-0.6098049879074097,-0.663641095161438,-0.6747554540634155,-0.6536675095558167,-0.6562013626098633,-0.6483560800552368,-0.6490122675895691,-0.6614961624145508,-0.6567068696022034,-0.6308799386024475,-0.629096508026123,-0.5973249077796936,-0.6452592015266418,-0.672990083694458,-0.6532180309295654, ...

# %%
data_extractor.experiment_manager.variant_dir
# Out:
# PosixPath('/content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/ANERCorp_CamelLab_arabertv02')

# %%
data_extractor.analysis_extraction_pipeline.outputs.keys()
# Out:
# dict_keys(['analysis_data', 'entity_report', 'token_report', 'results', 'kmeans_results', 'centroids_avg_similarity_matrix', 'attention_similarity_heatmap', 'attention_similarity_matrix', 'attention_weights_similarity_heatmap', 'attention_weights_similarity_matrix', 'entity_confusion_data'])

# %%
env_setup.save_environment_info(data_extractor.experiment_manager.variant_dir)
# Out:
# INFO:root:Python version saved to /content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/ANERCorp_CamelLab_arabertv02/python_version.txt
# INFO:root:Installed packages saved to /content/drive/My Drive/Final Year Experiments/Thesis-Experiments/Experiments/BaseLineExperiment/ANERCorp_CamelLab_arabertv02/requirements.txt
