# %%
if 'google.colab' in str(get_ipython()):
    from google.colab import userdata
    access_token = userdata.get('DEFORMER_TOKEN')
    # !pip install git+https://$access_token@github.com/ay94/deformer-extractor.git@error-handling
# Out:
# ...
#   Cloning https://****@github.com/ay94/deformer-extractor.git (to revision error-handling) to /tmp/pip-req-build-st6hifdt
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/ay94/deformer-extractor.git' /tmp/pip-req-build-st6hifdt
#   Running command git checkout -b error-handling --track origin/error-handling
#   Switched to a new branch 'error-handling'
#   Branch 'error-handling' set up to track remote branch 'error-handling' from 'origin'.
#   Resolved https://****@github.com/ay94/deformer-extractor.git to commit 178458bca6368818018b1ed3b816587561074e07
#   Preparing metadata (setup.py) ... done
# ...

# %%
from experiment_utils import colab
from experiment_utils.general_utils import FileHandler, DataManager

# %%
base_folder = colab.init('My Drive')
config_path = base_folder / 'Final Year Experiments/Thesis-Experiments/RawData/config.yaml'
experiment_path = base_folder / 'Final Year Experiments/Thesis-Experiments/ExperimentData'
# Out:
# Mounted at /content/drive

# %%
data_manager = DataManager(config_path)
corpora = data_manager.generate_corpora()
# Out:
# ...
# Generating train split:   0%|          | 0/14041 [00:00<?, ? examples/s]
# INFO:datasets_modules.datasets.conll2003.9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98.conll2003:⏳ Generating examples from = /root/.cache/huggingface/datasets/downloads/extracted/fb350f14aaa0ce8a148eb2de9b8f4c19422485ca2524f6b4170579a4759a2d51/train.txt
# Generating validation split:   0%|          | 0/3250 [00:00<?, ? examples/s]
# INFO:datasets_modules.datasets.conll2003.9a4d16a94f8674ba3466315300359b0acd891b68b6c8743ddf60b9c702adce98.conll2003:⏳ Generating examples from = /root/.cache/huggingface/datasets/downloads/extracted/fb350f14aaa0ce8a148eb2de9b8f4c19422485ca2524f6b4170579a4759a2d51/valid.txt
# Generating test split:   0%|          | 0/3453 [00:00<?, ? examples/s]
# ...

# %%
# Example of saving the generated corpora
output_handler = FileHandler(experiment_path)
output_handler.save_json('corpora.json', corpora)
